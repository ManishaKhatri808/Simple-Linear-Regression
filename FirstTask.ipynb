# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score

# %%
df=pd.read_csv('D:\FirstProject\FirstProject.csv')

# %%
df.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
df.nunique()
# Out:
# Hours     23
# Scores    23
# dtype: int64

# %%
percentages=df['Scores']
hours=df['Hours']
fig,ax=plt.subplots(figsize=(10,5))
ax.bar(percentages,hours)
ax.set_title('Percentage of students by hours of study')
ax.set_xlabel('Percentage')
ax.set_ylabel('Hours of study')
# Out:
# Text(0, 0.5, 'Hours of study')

# %%
plt.scatter(percentages,hours)

# %%
x=df.iloc[:,0].values
y=df.iloc[:,1].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
x_train = x_train.reshape(-1, 1)
x_test=x_test.reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=lr.predict(x_test)

# %%
y_predict
# Out:
# array([16.88414476, 33.73226078, 75.357018  , 26.79480124, 60.49103328])

# %%
line = lr.coef_*x+lr.intercept_
plt.scatter(x,y)
plt.plot(x,line)

# %%
y_predict = lr.predict(x_test)
print(y_predict)
# Out:
# [16.88414476 33.73226078 75.357018   26.79480124 60.49103328]

# %%
hours=5.5
predicted_hours=lr.predict([[hours]])
predicted_hours
# Out:
# array([56.52677068])

# %%
predicted_hours[0]
# Out:
# 56.526770684966976

# %%
from sklearn import metrics  
print('Mean Absolute Error:', 
metrics.mean_absolute_error(y_test, y_predict))
# Out:
# Mean Absolute Error: 4.183859899002975
